# %%
from Bio import SeqIO
import numpy as np
import pandas as pd
import primer3

# get reverse complementary sequence for reverse primer
def getRevComp(sequence):
    dicComp = {'A':'T',
                'T':'A',
                'C':'G',
                'G':'C',
                'N':'N'}
    revComp = []
    for i in sequence[::-1]:
        revComp.append(dicComp[i])
    return ''.join(revComp)

# %%
parse = [x for x in SeqIO.parse('./matK_prank.fasta.best.fas','fasta')]
# parse = [x for x in SeqIO.parse('./matK_prank.best.nex','nexus')]

def ExtractSeqBetweenSNP(parse):
    seq      = []
    for i in parse:
        seq.append([nt for nt in i.seq])
    nex_seq  = np.array(seq).T
    df       = pd.DataFrame(nex_seq, columns=[x.id for x in parse])
    
    # make SNP index list
    listSNPix = []
    for ix in df.index:
        if len(set(df.loc[ix].values)) != 1:
            listSNPix.append(ix)
    listSNPix.append(len(df))
    
    # make text file of seq between SNPs
    with open('./seq_between_snps.txt','w') as f:
        print('start_loc','length','sequence',file=f)
        try:
            for ix in range(len(listSNPix)):
                piece_len = listSNPix[ix+1]-listSNPix[ix]-1
                if piece_len >= 18:
                    print(listSNPix[ix]+1,piece_len,
                          parse[0].seq[listSNPix[ix]+1:listSNPix[ix]+piece_len+1],
                          file=f)
        except IndexError:
            pass

# %%
ExtractSeqBetweenSNP(parse)

# %%
def ExtractCandidatePrimer(SeqBetweenSNPs):
    df_seq_between_snps = pd.read_csv(SeqBetweenSNPs,sep=' ')
    dic_candidate_primer = {
        'sequence'         : [],
        'reverse_sequence' : [],
        'start_loc'        : [],
        'length'           : [],
        'Tm'               : [],
        'GCcontents (%)'   : [],
        'hairpin'          : []
    }
    # extract candidate primers : > 18 length
    for ix in range(len(df_seq_between_snps)):
        i = 0
        while i < 50:
            if len(df_seq_between_snps.loc[ix]['sequence'][0+i:20+i]) in range(18,23):

                sequence         = df_seq_between_snps.loc[ix]['sequence'][0+i:20+i]
                reverse_sequence = getRevComp(sequence)
                start_loc        = int(df_seq_between_snps.loc[ix]['start_loc'])+i
                length           = len(sequence)
                Tm               = primer3.calcTm(sequence)
                GCcontents       = (sequence.count('C')+sequence.count('G'))/len(sequence)*100
                hairpin          = primer3.calcHairpin(sequence)

                dic_candidate_primer['sequence'].append(sequence)
                dic_candidate_primer['reverse_sequence'].append(reverse_sequence)
                dic_candidate_primer['start_loc'].append(start_loc)
                dic_candidate_primer['length'].append(length)
                dic_candidate_primer['Tm'].append(Tm)
                dic_candidate_primer['GCcontents (%)'].append(GCcontents)
                dic_candidate_primer['hairpin'].append(hairpin)
                i = i+1
            else:
                break
    df_candidate_primer = pd.DataFrame(dic_candidate_primer)
    
    # setting primer conditions
    m1  = df_candidate_primer['Tm'] >= 40            # normally 50~60 °C
    m2  = df_candidate_primer['length'] >= 18        # normally 18~24 mer
    m3  = df_candidate_primer['GCcontents (%)'] > 40 # normally 50 %
    m   = m1 & m2 & m3
    df_candidate_primer_m = df_candidate_primer[m]
    return df_candidate_primer_m

# %%
ExtractCandidatePrimer('./seq_between_snps.txt')
# Out:
# 169    GACCGATTTGTCAGATTC    GAATCTGACAAATCGGTC       1193      18  45.011165
# 201  CTTAGACTTTCATGTGCTCG  CGAGCACATGAAAGTCTAAG       1308      20  48.591408
# 202   TTAGACTTTCATGTGCTCG   CGAGCACATGAAAGTCTAA       1309      19  47.128459
# 203    TAGACTTTCATGTGCTCG    CGAGCACATGAAAGTCTA       1310      18  46.121695
#
#      GCcontents (%)                                            hairpin
# 23        45.000000  ThermoResult(structure_found=False, tm=0.00, d...
# 57        45.000000  ThermoResult(structure_found=True, tm=49.41, d...
# 58        50.000000  ThermoResult(structure_found=True, tm=49.41, d...
# 59        45.000000  ThermoResult(structure_found=True, tm=49.41, d...
# 60        45.000000  ThermoResult(structure_found=True, tm=42.65, d...
# 61        45.000000  ThermoResult(structure_found=False, tm=0.00, d...
# 122       55.000000  ThermoResult(structure_found=True, tm=38.76, d...
# 123       55.000000  ThermoResult(structure_found=True, tm=37.51, d...
# 124       55.000000  ThermoResult(structure_found=True, tm=37.51, d...
# 125       55.000000  ThermoResult(structure_found=True, tm=40.64, d...
# 126       50.000000  ThermoResult(structure_found=True, tm=37.95, d...
# 127       45.000000  ThermoResult(structure_found=True, tm=37.95, d...
# 149       45.000000  ThermoResult(structure_found=False, tm=0.00, d...
# 150       45.000000  ThermoResult(structure_found=True, tm=39.34, d...
# 152       45.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 153       50.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 154       55.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 155       55.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 156       55.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 157       50.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 158       45.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 159       50.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 160       50.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 161       50.000000  ThermoResult(structure_found=True, tm=35.79, d...
# 162       45.000000  ThermoResult(structure_found=True, tm=33.47, d...
# 163       45.000000  ThermoResult(structure_found=True, tm=33.47, d...
# 164       45.000000  ThermoResult(structure_found=True, tm=33.47, d...
# 167       45.000000  ThermoResult(structure_found=True, tm=33.47, d...
# 168       47.368421  ThermoResult(structure_found=True, tm=33.47, d...
# 169       44.444444  ThermoResult(structure_found=True, tm=32.09, d...
# 201       45.000000  ThermoResult(structure_found=False, tm=0.00, d...
# 202       42.105263  ThermoResult(structure_found=False, tm=0.00, d...
# 203       44.444444  ThermoResult(structure_found=False, tm=0.00, d...

# %%
df_candidate_primer_m = ExtractCandidatePrimer('./seq_between_snps.txt')

primer_f = df_candidate_primer_m.loc[61]['sequence']
primer_r = df_candidate_primer_m.loc[149]['reverse_sequence']

# %%
primer_f,primer_r
# Out:
# ('GGATACATGATGTTCCCACT', 'CAAACTGGCTTGCTAATAGG')

# %%
primer3.calcHeterodimer(primer_f,primer_r)
# Out:
# ThermoResult(structure_found=True, tm=-46.05, dg=-1452.28, dh=-26700.00, ds=-81.40)
